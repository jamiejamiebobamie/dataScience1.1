# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
git add .
# Out:
#   File "<ipython-input-2-3d6cfb4a5e4d>", line 1
#     git add .
#           ^
# SyntaxError: invalid syntax

# %%
import numpy as np
from scipy import stats

# %%
DATASET2017 = "datasets/NPS/surveys/2017/survey1.csv"

# %%
df2017 = pd.read_csv(DATASET2017)

# %%
df.count()
# Out:
# ID                 1453
# Location           1406
# Track              1406
# Week               1453
# Rating (Num)       1453
# Schedule Pacing    1450
# dtype: int64

# %%
df["Rating (Num)"]
# Out:
# 0        3
# 1        4
# 2        4
# 3        4
# 4        4
# 5        5
# 6        5
# 7        5
# 8        5
# 9        5
# 10       5
# 11       5
# 12       5
# 13       5
# 14       5
# 15       5
# 16       5
# 17       5
# 18       5
# 19       5
# 20       6
# 21       6
# 22       6
# 23       6
# 24       6
# 25       6
# 26       6
# 27       6
# 28       6
# 29       6
#         ..
# 1423    10
# 1424     8
# 1425     9
# 1426    10
# 1427     9
# 1428     9
# 1429     8
# 1430    10
# 1431    10
# 1432     9
# 1433     9
# 1434    10
# 1435     8
# 1436     7
# 1437     7
# 1438     7
# 1439     9
# 1440     8
# 1441     7
# 1442    10
# 1443    10
# 1444     9
# 1445     9
# 1446     3
# 1447    10
# 1448    10
# 1449     8
# 1450    10
# 1451     1
# 1452     8
# Name: Rating (Num), Length: 1453, dtype: object

# %%
df[NaN]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-095c698bb40f> in <module>
# ----> 1 df[NaN]
#
# NameError: name 'NaN' is not defined

# %%
df
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 0      134  San Francisco   Apps, Explorer  Week 1            3
# 1       36    Los Angeles             Apps  Week 1            4
# 2      117  San Francisco            Games  Week 1            4
# 3      253            NaN              NaN  Week 2            4
# 4      350  New York City   Apps, Explorer  Week 1            4
# 5       23   Redwood City             Apps  Week 1            5
# 6       28    Los Angeles             Apps  Week 7            5
# 7       65  San Francisco             Apps  Week 1            5
# 8      101    Santa Clara             Apps  Week 1            5
# 9      124    Santa Clara             Apps  Week 1            5
# 10     157   Redwood City             Apps  Week 2            5
# 11     170        Oakland             Apps  Week 2            5
# 12     255  San Francisco             Apps  Week 2            5
# 13     289  Washington DC             Apps  Week 1            5
# ...

# %%
df["Year"] = 2017

# %%
df
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 0      134  San Francisco   Apps, Explorer  Week 1            3
# 1       36    Los Angeles             Apps  Week 1            4
# 2      117  San Francisco            Games  Week 1            4
# 3      253            NaN              NaN  Week 2            4
# 4      350  New York City   Apps, Explorer  Week 1            4
# 5       23   Redwood City             Apps  Week 1            5
# 6       28    Los Angeles             Apps  Week 7            5
# 7       65  San Francisco             Apps  Week 1            5
# 8      101    Santa Clara             Apps  Week 1            5
# 9      124    Santa Clara             Apps  Week 1            5
# 10     157   Redwood City             Apps  Week 2            5
# 11     170        Oakland             Apps  Week 2            5
# 12     255  San Francisco             Apps  Week 2            5
# 13     289  Washington DC             Apps  Week 1            5
# ...

# %%
df["Rating (Num)"].dropna().values
# Out:
# array(['3', '4', '4', ..., '10', '1', '8'], dtype=object)

# %%
df
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 0      134  San Francisco   Apps, Explorer  Week 1            3
# 1       36    Los Angeles             Apps  Week 1            4
# 2      117  San Francisco            Games  Week 1            4
# 3      253            NaN              NaN  Week 2            4
# 4      350  New York City   Apps, Explorer  Week 1            4
# 5       23   Redwood City             Apps  Week 1            5
# 6       28    Los Angeles             Apps  Week 7            5
# 7       65  San Francisco             Apps  Week 1            5
# 8      101    Santa Clara             Apps  Week 1            5
# 9      124    Santa Clara             Apps  Week 1            5
# 10     157   Redwood City             Apps  Week 2            5
# 11     170        Oakland             Apps  Week 2            5
# 12     255  San Francisco             Apps  Week 2            5
# 13     289  Washington DC             Apps  Week 1            5
# ...

# %%
df
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 0      134  San Francisco   Apps, Explorer  Week 1            3
# 1       36    Los Angeles             Apps  Week 1            4
# 2      117  San Francisco            Games  Week 1            4
# 3      253            NaN              NaN  Week 2            4
# 4      350  New York City   Apps, Explorer  Week 1            4
# 5       23   Redwood City             Apps  Week 1            5
# 6       28    Los Angeles             Apps  Week 7            5
# 7       65  San Francisco             Apps  Week 1            5
# 8      101    Santa Clara             Apps  Week 1            5
# 9      124    Santa Clara             Apps  Week 1            5
# 10     157   Redwood City             Apps  Week 2            5
# 11     170        Oakland             Apps  Week 2            5
# 12     255  San Francisco             Apps  Week 2            5
# 13     289  Washington DC             Apps  Week 1            5
# ...

# %%
df['Score'] = df["Rating (Num)"]

# %%
df
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 0      134  San Francisco   Apps, Explorer  Week 1            3
# 1       36    Los Angeles             Apps  Week 1            4
# 2      117  San Francisco            Games  Week 1            4
# 3      253            NaN              NaN  Week 2            4
# 4      350  New York City   Apps, Explorer  Week 1            4
# 5       23   Redwood City             Apps  Week 1            5
# 6       28    Los Angeles             Apps  Week 7            5
# 7       65  San Francisco             Apps  Week 1            5
# 8      101    Santa Clara             Apps  Week 1            5
# 9      124    Santa Clara             Apps  Week 1            5
# 10     157   Redwood City             Apps  Week 2            5
# 11     170        Oakland             Apps  Week 2            5
# 12     255  San Francisco             Apps  Week 2            5
# 13     289  Washington DC             Apps  Week 1            5
# ...

# %%
df.drop(['Rating (Num)'], axis=1)
# Out:
#         ID       Location            Track    Week    Schedule Pacing  Year  \
# 0      134  San Francisco   Apps, Explorer  Week 1         Just right  2017
# 1       36    Los Angeles             Apps  Week 1  A little too fast  2017
# 2      117  San Francisco            Games  Week 1       Way too slow  2017
# 3      253            NaN              NaN  Week 2  A little too fast  2017
# 4      350  New York City   Apps, Explorer  Week 1         Just right  2017
# 5       23   Redwood City             Apps  Week 1         Just right  2017
# 6       28    Los Angeles             Apps  Week 7         Just right  2017
# 7       65  San Francisco             Apps  Week 1  A little too slow  2017
# 8      101    Santa Clara             Apps  Week 1  A little too slow  2017
# 9      124    Santa Clara             Apps  Week 1         Just right  2017
# 10     157   Redwood City             Apps  Week 2         Just right  2017
# ...

# %%
df["Score"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        3
# 1        4
# 2        4
# 3        4
# 4        4
# 5        5
# 6        5
# 7        5
# 8        5
# 9        5
# 10       5
# 11       5
# 12       5
# 13       5
# 14       5
# 15       5
# 16       5
# 17       5
# 18       5
# 19       5
# 20       6
# 21       6
# 22       6
# 23       6
# 24       6
# 25       6
# 26       6
# 27       6
# 28       6
# 29       6
#         ..
# 1423    10
# 1424     8
# 1425     9
# 1426    10
# 1427     9
# 1428     9
# 1429     8
# 1430    10
# 1431    10
# 1432     9
# 1433     9
# 1434    10
# 1435     8
# 1436     7
# 1437     7
# 1438     7
# 1439     9
# 1440     8
# 1441     7
# 1442    10
# 1443    10
# 1444     9
# 1445     9
# 1446     3
# 1447    10
# 1448    10
# 1449     8
# 1450    10
# 1451     1
# 1452     8
# Name: Score, Length: 1453, dtype: object>

# %%
df["Score"].unique()
# Out:
# array(['3', '4', '5', '6', '7', '8', '9', '10', '0', '1', '2', '#ERROR!'],
#       dtype=object)

# %%
df[(df["Score"] == '#ERROR!')]
# Out:
#         ID Location Track    Week Rating (Num) Schedule Pacing  Year    Score
# 1310  1356      NaN   NaN  Week 2      #ERROR!             NaN  2017  #ERROR!
# 1322  1368      NaN   NaN  Week 3      #ERROR!             NaN  2017  #ERROR!
# 1411  1458      NaN   NaN  Week 3      #ERROR!             NaN  2017  #ERROR!

# %%
df_backup = df

# %%
df.drop(1310)
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 0      134  San Francisco   Apps, Explorer  Week 1            3
# 1       36    Los Angeles             Apps  Week 1            4
# 2      117  San Francisco            Games  Week 1            4
# 3      253            NaN              NaN  Week 2            4
# 4      350  New York City   Apps, Explorer  Week 1            4
# 5       23   Redwood City             Apps  Week 1            5
# 6       28    Los Angeles             Apps  Week 7            5
# 7       65  San Francisco             Apps  Week 1            5
# 8      101    Santa Clara             Apps  Week 1            5
# 9      124    Santa Clara             Apps  Week 1            5
# 10     157   Redwood City             Apps  Week 2            5
# 11     170        Oakland             Apps  Week 2            5
# 12     255  San Francisco             Apps  Week 2            5
# 13     289  Washington DC             Apps  Week 1            5
# ...

# %%
df[(df["Score"] == '#ERROR!')]
# Out:
#         ID Location Track    Week Rating (Num) Schedule Pacing  Year    Score
# 1310  1356      NaN   NaN  Week 2      #ERROR!             NaN  2017  #ERROR!
# 1322  1368      NaN   NaN  Week 3      #ERROR!             NaN  2017  #ERROR!
# 1411  1458      NaN   NaN  Week 3      #ERROR!             NaN  2017  #ERROR!

# %%
df = df_backup

# %%
df
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 0      134  San Francisco   Apps, Explorer  Week 1            3
# 1       36    Los Angeles             Apps  Week 1            4
# 2      117  San Francisco            Games  Week 1            4
# 3      253            NaN              NaN  Week 2            4
# 4      350  New York City   Apps, Explorer  Week 1            4
# 5       23   Redwood City             Apps  Week 1            5
# 6       28    Los Angeles             Apps  Week 7            5
# 7       65  San Francisco             Apps  Week 1            5
# 8      101    Santa Clara             Apps  Week 1            5
# 9      124    Santa Clara             Apps  Week 1            5
# 10     157   Redwood City             Apps  Week 2            5
# 11     170        Oakland             Apps  Week 2            5
# 12     255  San Francisco             Apps  Week 2            5
# 13     289  Washington DC             Apps  Week 1            5
# ...

# %%
df.drop([1310, 1322,1411])
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 0      134  San Francisco   Apps, Explorer  Week 1            3
# 1       36    Los Angeles             Apps  Week 1            4
# 2      117  San Francisco            Games  Week 1            4
# 3      253            NaN              NaN  Week 2            4
# 4      350  New York City   Apps, Explorer  Week 1            4
# 5       23   Redwood City             Apps  Week 1            5
# 6       28    Los Angeles             Apps  Week 7            5
# 7       65  San Francisco             Apps  Week 1            5
# 8      101    Santa Clara             Apps  Week 1            5
# 9      124    Santa Clara             Apps  Week 1            5
# 10     157   Redwood City             Apps  Week 2            5
# 11     170        Oakland             Apps  Week 2            5
# 12     255  San Francisco             Apps  Week 2            5
# 13     289  Washington DC             Apps  Week 1            5
# ...

# %%
df_backup2 = df[(df["Score"] != '#ERROR!')]

# %%
df_backup2
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 0      134  San Francisco   Apps, Explorer  Week 1            3
# 1       36    Los Angeles             Apps  Week 1            4
# 2      117  San Francisco            Games  Week 1            4
# 3      253            NaN              NaN  Week 2            4
# 4      350  New York City   Apps, Explorer  Week 1            4
# 5       23   Redwood City             Apps  Week 1            5
# 6       28    Los Angeles             Apps  Week 7            5
# 7       65  San Francisco             Apps  Week 1            5
# 8      101    Santa Clara             Apps  Week 1            5
# 9      124    Santa Clara             Apps  Week 1            5
# 10     157   Redwood City             Apps  Week 2            5
# 11     170        Oakland             Apps  Week 2            5
# 12     255  San Francisco             Apps  Week 2            5
# 13     289  Washington DC             Apps  Week 1            5
# ...

# %%
df_backup2["Score"].unique()
# Out:
# array(['3', '4', '5', '6', '7', '8', '9', '10', '0', '1', '2'],
#       dtype=object)

# %%
df_backup2 = df_backup2.drop(['Rating (Num)'], axis=1)

# %%
df_backup2
# Out:
#         ID       Location            Track    Week    Schedule Pacing  Year  \
# 0      134  San Francisco   Apps, Explorer  Week 1         Just right  2017
# 1       36    Los Angeles             Apps  Week 1  A little too fast  2017
# 2      117  San Francisco            Games  Week 1       Way too slow  2017
# 3      253            NaN              NaN  Week 2  A little too fast  2017
# 4      350  New York City   Apps, Explorer  Week 1         Just right  2017
# 5       23   Redwood City             Apps  Week 1         Just right  2017
# 6       28    Los Angeles             Apps  Week 7         Just right  2017
# 7       65  San Francisco             Apps  Week 1  A little too slow  2017
# 8      101    Santa Clara             Apps  Week 1  A little too slow  2017
# 9      124    Santa Clara             Apps  Week 1         Just right  2017
# 10     157   Redwood City             Apps  Week 2         Just right  2017
# ...

# %%
df_backup2.describe
# Out:
# <bound method NDFrame.describe of         ID       Location            Track    Week    Schedule Pacing  Year  \
# 0      134  San Francisco   Apps, Explorer  Week 1         Just right  2017
# 1       36    Los Angeles             Apps  Week 1  A little too fast  2017
# 2      117  San Francisco            Games  Week 1       Way too slow  2017
# 3      253            NaN              NaN  Week 2  A little too fast  2017
# 4      350  New York City   Apps, Explorer  Week 1         Just right  2017
# 5       23   Redwood City             Apps  Week 1         Just right  2017
# 6       28    Los Angeles             Apps  Week 7         Just right  2017
# 7       65  San Francisco             Apps  Week 1  A little too slow  2017
# 8      101    Santa Clara             Apps  Week 1  A little too slow  2017
# 9      124    Santa Clara             Apps  Week 1         Just right  2017
# 10     157   Redwood City             Apps  Week 2         Just right  2017
# ...

# %%
df = df_backup2

# %%
df.shape
# Out:
# (1450, 7)

# %%
df["Score"].unique()
# Out:
# array(['3', '4', '5', '6', '7', '8', '9', '10', '0', '1', '2'],
#       dtype=object)

# %%
df[(df["Score"] == '10')]
# Out:
# <bound method DataFrame.count of         ID       Location            Track    Week    Schedule Pacing  Year  \
# 376     12        Atlanta             Apps  Week 1         Just right  2017
# 377     13        Atlanta   Apps, Explorer  Week 1         Just right  2017
# 378     17   Redwood City             Apps  Week 1         Just right  2017
# 379     19   Redwood City             Apps  Week 1         Just right  2017
# 380     22   Redwood City             Apps  Week 1         Just right  2017
# 381     24   Redwood City             Apps  Week 1  A little too fast  2017
# 382     34    Los Angeles             Apps  Week 1         Just right  2017
# 383     42        Chicago             Apps  Week 1         Just right  2017
# 384     43        Chicago   Apps, Explorer  Week 1         Just right  2017
# 385     44        Chicago             Apps  Week 1  A little too fast  2017
# 386     49  San Francisco               VR  Week 1         Just right  2017
# ...

# %%
df["NPS"] = df['Score'].map({'10': 1, '9': 1, '8': 0, '7': 0, '6': -1, '5': -1, '4': -1, '3': -1, '2': -1, '1': -1})

# %%
df
# Out:
#         ID       Location            Track    Week    Schedule Pacing  Year  \
# 0      134  San Francisco   Apps, Explorer  Week 1         Just right  2017
# 1       36    Los Angeles             Apps  Week 1  A little too fast  2017
# 2      117  San Francisco            Games  Week 1       Way too slow  2017
# 3      253            NaN              NaN  Week 2  A little too fast  2017
# 4      350  New York City   Apps, Explorer  Week 1         Just right  2017
# 5       23   Redwood City             Apps  Week 1         Just right  2017
# 6       28    Los Angeles             Apps  Week 7         Just right  2017
# 7       65  San Francisco             Apps  Week 1  A little too slow  2017
# 8      101    Santa Clara             Apps  Week 1  A little too slow  2017
# 9      124    Santa Clara             Apps  Week 1         Just right  2017
# 10     157   Redwood City             Apps  Week 2         Just right  2017
# ...

# %%
NPS_count = df[(df["NPS"] == 1.0)].count() - df[(df["NPS"] == -1.0)].count() / df.count()

# %%
NPS_count
# Out:
# ID                 641
# Location           627
# Track              627
# Week               641
# Schedule Pacing    641
# Year               641
# Score              641
# NPS                641
# dtype: int64

# %%
df.count()
# Out:
# ID                 1450
# Location           1406
# Track              1406
# Week               1450
# Schedule Pacing    1450
# Year               1450
# Score              1450
# NPS                1448
# dtype: int64

# %%
NPS_count/df.count()
# Out:
# ID                 0.442069
# Location           0.445946
# Track              0.445946
# Week               0.442069
# Schedule Pacing    0.442069
# Year               0.442069
# Score              0.442069
# NPS                0.442680
# dtype: float64

# %%
NPS_seventeen_NPS_score = (df[(df["NPS"] == 1.0)].count() - df[(df["NPS"] == -1.0)].count()) / df.count()

# %%
NPS_seventeen_NPS_score = (df[(df["NPS"] == 1.0)].count() - df[(df["NPS"] == -1.0)].count()) / df.count()

# %%
NPS_seventeen_NPS_score * 100
# Out:
# ID                 44.206897
# Location           44.594595
# Track              44.594595
# Week               44.206897
# Schedule Pacing    44.206897
# Year               44.206897
# Score              44.206897
# NPS                44.267956
# dtype: float64

# %%
NPS_seventeen_NPS_score["NPS"]
# Out:
# 0.44267955801104975

# %%
NPS_seventeen_NPS_score = int(NPS_seventeen_NPS_score["NPS"]*100)

# %%
NPS_seventeen_NPS_score
# Out:
# 44

# %%
df["NPS_2017_score"] = NPS_seventeen_NPS_score

# %%
df
# Out:
#         ID       Location            Track    Week    Schedule Pacing  Year  \
# 0      134  San Francisco   Apps, Explorer  Week 1         Just right  2017
# 1       36    Los Angeles             Apps  Week 1  A little too fast  2017
# 2      117  San Francisco            Games  Week 1       Way too slow  2017
# 3      253            NaN              NaN  Week 2  A little too fast  2017
# 4      350  New York City   Apps, Explorer  Week 1         Just right  2017
# 5       23   Redwood City             Apps  Week 1         Just right  2017
# 6       28    Los Angeles             Apps  Week 7         Just right  2017
# 7       65  San Francisco             Apps  Week 1  A little too slow  2017
# 8      101    Santa Clara             Apps  Week 1  A little too slow  2017
# 9      124    Santa Clara             Apps  Week 1         Just right  2017
# 10     157   Redwood City             Apps  Week 2         Just right  2017
# ...

# %%
df_1 = df #2017 FINAL

# %%
df_1["Year"] = 2017

# %%
DATASET_1_LA = "datasets/NPS/surveys/2016_renamed/2016Week1-LA.csv"

# %%
df_1_LA = pd.read_csv(DATASET_1_LA)

# %%
df_1_LA
# Out:
#             Timestamp  \
# 0  6/23/2016 15:55:12
# 1  6/23/2016 16:14:04
# 2   6/24/2016 0:18:42
# 3   6/24/2016 6:59:42
# 4   6/24/2016 9:40:16
# 5  6/23/2016 22:07:29
# 6   6/24/2016 9:34:14
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
# 5                                                  5
# 6                                                  5
#
#    How well are the tutorials paced?
# 0                                  4
# 1                                  4
# 2                                  4
# 3                                  4
# 4                                  5
# 5                                  4
# 6                                  3

# %%
df_1_LA = df_1_LA.rename(index=str, columns={"How would you rate your overall satisfaction with the Summer Academy this week?": "Score", "How well are the tutorials paced?": "Schedule Pacing"})

# %%
df_1_LA["Location"] = "Los Angeles"

# %%
df_1_LA
# Out:
#             Timestamp  Score  Schedule Pacing     Location
# 0  6/23/2016 15:55:12      3                4  Los Angeles
# 1  6/23/2016 16:14:04      4                4  Los Angeles
# 2   6/24/2016 0:18:42      4                4  Los Angeles
# 3   6/24/2016 6:59:42      4                4  Los Angeles
# 4   6/24/2016 9:40:16      4                5  Los Angeles
# 5  6/23/2016 22:07:29      5                4  Los Angeles
# 6   6/24/2016 9:34:14      5                3  Los Angeles

# %%
df_1_LA["Year"] = 2016

# %%
df_1_LA #final for 2016 week 1 LA
# Out:
#             Timestamp  Score  Schedule Pacing     Location  Year
# 0  6/23/2016 15:55:12      3                4  Los Angeles  2016
# 1  6/23/2016 16:14:04      4                4  Los Angeles  2016
# 2   6/24/2016 0:18:42      4                4  Los Angeles  2016
# 3   6/24/2016 6:59:42      4                4  Los Angeles  2016
# 4   6/24/2016 9:40:16      4                5  Los Angeles  2016
# 5  6/23/2016 22:07:29      5                4  Los Angeles  2016
# 6   6/24/2016 9:34:14      5                3  Los Angeles  2016

# %%
all_csvs = glob.glob(os.path.join('datasets/NPS/surveys/2016_renamed/weeks1_7', '*.csv'))
read_all_csvs = (pd.read_csv(f) for f in all_csvs)
df = pd.concat(read_all_csvs, ignore_index = True, sort = True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-173-a420d8d92877> in <module>
# ----> 1 all_csvs = glob.glob(os.path.join('datasets/NPS/surveys/2016_renamed/weeks1_7', '*.csv'))
#       2 read_all_csvs = (pd.read_csv(f) for f in all_csvs)
#       3 df = pd.concat(read_all_csvs, ignore_index = True, sort = True)
#       4 df.head()
#
# NameError: name 'glob' is not defined

# %%
import glob as glob

# %%
all_csvs = glob.glob(os.path.join('datasets/NPS/surveys/2016_renamed/weeks1_7', '*.csv'))
read_all_csvs = (pd.read_csv(f) for f in all_csvs)
df = pd.concat(read_all_csvs, ignore_index = True, sort = True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-175-a420d8d92877> in <module>
# ----> 1 all_csvs = glob.glob(os.path.join('datasets/NPS/surveys/2016_renamed/weeks1_7', '*.csv'))
#       2 read_all_csvs = (pd.read_csv(f) for f in all_csvs)
#       3 df = pd.concat(read_all_csvs, ignore_index = True, sort = True)
#       4 df.head()
#
# NameError: name 'os' is not defined

# %%
import os

# %%
all_csvs = glob.glob(os.path.join('datasets/NPS/surveys/2016_renamed/weeks1_7', '*.csv'))
read_all_csvs = (pd.read_csv(f) for f in all_csvs)
df = pd.concat(read_all_csvs, ignore_index = True, sort = True)
df.head()
# Out:
#    How well are the tutorials paced? How well is the schedule paced?  \
# 0                                NaN                               3
# 1                                NaN                               3
# 2                                NaN                               3
# 3                                NaN                               3
# 4                                NaN                               3
#
#   How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  5
# 1                                                  4
# 2                                                  5
# 3                                                  4
# 4                                                  5
#
#             Timestamp Unnamed: 0 What track are you in?
# 0   7/29/2016 0:19:08        NaN                    NaN
# 1   7/29/2016 0:22:41        NaN                    NaN
# ...

# %%
df
# Out:
#      How well are the tutorials paced? How well is the schedule paced?  \
# 0                                  NaN                               3
# 1                                  NaN                               3
# 2                                  NaN                               3
# 3                                  NaN                               3
# 4                                  NaN                               3
# 5                                  NaN                               4
# 6                                  NaN                               3
# 7                                  NaN                               3
# 8                                  NaN                               3
# 9                                  NaN                               3
# 10                                 NaN                               3
# 11                                 NaN                               2
# ...

# %%
all_csvs = glob.glob(os.path.join('datasets/NPS/surveys/2016_renamed/weeks1_7/HK', '*.csv'))
read_all_csvs = (pd.read_csv(f) for f in all_csvs)
df = pd.concat(read_all_csvs, ignore_index = True, sort = True)
df.head()
# Out:
#    How well are the tutorials paced?  How well is the schedule paced?  \
# 0                                NaN                              3.0
# 1                                NaN                              3.0
# 2                                NaN                              3.0
# 3                                3.0                              NaN
# 4                                3.0                              NaN
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  5
# 1                                                  4
# 2                                                  5
# 3                                                  4
# 4                                                  5
#
#             Timestamp
# 0   7/29/2016 0:19:08
# 1   7/29/2016 0:22:41
# 2   7/29/2016 0:23:17
# 3  7/21/2016 21:57:59
# 4  7/21/2016 21:59:37

# %%
df['Location'] = 'Hong Kong'

# %%
df_HK = df

# %%
all_csvs = glob.glob(os.path.join('datasets/NPS/surveys/2016_renamed/weeks1_7/LA', '*.csv'))
read_all_csvs = (pd.read_csv(f) for f in all_csvs)
df = pd.concat(read_all_csvs, ignore_index = True, sort = True)
df.head()
# Out:
#    How well are the tutorials paced?  How well is the schedule paced?  \
# 0                                NaN                              2.0
# 1                                NaN                              3.0
# 2                                NaN                              4.0
# 3                                NaN                              3.0
# 4                                NaN                              3.0
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#             Timestamp What track are you in?
# 0  6/30/2016 14:09:14                    NaN
# 1  6/30/2016 22:50:08                    NaN
# 2    7/1/2016 9:34:16                    NaN
# ...

# %%
df['Location'] = 'Los Angeles'

# %%
df_LA = df

# %%
all_csvs = glob.glob(os.path.join('datasets/NPS/surveys/2016_renamed/weeks1_7/NY', '*.csv'))
read_all_csvs = (pd.read_csv(f) for f in all_csvs)
df = pd.concat(read_all_csvs, ignore_index = True, sort = True)
df.head()
# Out:
#    How well are the tutorials paced?  How well is the schedule paced?  \
# 0                                NaN                              2.0
# 1                                NaN                              4.0
# 2                                NaN                              5.0
# 3                                NaN                              3.0
# 4                                NaN                              3.0
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#           Timestamp What track are you in?
# 0  7/1/2016 6:41:31                   Apps
# 1  7/1/2016 9:27:32                   Apps
# 2  7/1/2016 6:46:34                  Games
# ...

# %%
df['Location'] = 'New York'

# %%
df_NY = df

# %%
all_csvs = glob.glob(os.path.join('datasets/NPS/surveys/2016_renamed/weeks1_7/SF', '*.csv'))
read_all_csvs = (pd.read_csv(f) for f in all_csvs)
df = pd.concat(read_all_csvs, ignore_index = True, sort = True)
df.head()
# Out:
#    How well are the tutorials paced?  How well is the schedule paced?  \
# 0                                NaN                              3.0
# 1                                NaN                              3.0
# 2                                NaN                              4.0
# 3                                NaN                              4.0
# 4                                NaN                              4.0
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#             Timestamp What track are you in?
# 0  7/15/2016 15:26:38                   Apps
# 1  7/15/2016 15:31:37                   Apps
# 2  7/15/2016 15:32:59                   Apps
# ...

# %%
df['Location'] = 'San Francisco'

# %%
df_SF = df

# %%
all_csvs = glob.glob(os.path.join('datasets/NPS/surveys/2016_renamed/weeks1_7/SG', '*.csv'))
read_all_csvs = (pd.read_csv(f) for f in all_csvs)
df = pd.concat(read_all_csvs, ignore_index = True, sort = True)
df.head()
# Out:
#    How well are the tutorials paced?  How well is the schedule paced?  \
# 0                                NaN                              3.0
# 1                                NaN                              4.0
# 2                                NaN                              3.0
# 3                                NaN                              3.0
# 4                                NaN                              4.0
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  3
#
#            Timestamp
# 0  7/15/2016 2:45:00
# 1  7/15/2016 2:45:11
# 2  7/15/2016 2:48:37
# 3  7/15/2016 2:53:18
# 4  7/15/2016 2:56:09

# %%
df['Location'] = 'Singapore'

# %%
df_SG = df

# %%
all_csvs = glob.glob(os.path.join('datasets/NPS/surveys/2016_renamed/weeks1_7/SV', '*.csv'))
read_all_csvs = (pd.read_csv(f) for f in all_csvs)
df = pd.concat(read_all_csvs, ignore_index = True, sort = True)
df.head()
# Out:
#    How well are the tutorials paced? How well is the schedule paced?  \
# 0                                NaN                               3
# 1                                NaN                               3
# 2                                NaN                               4
# 3                                NaN                               3
# 4                                NaN                               3
#
#   How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  4
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  3
#
#             Timestamp Unnamed: 0 What track are you in?
# 0  7/29/2016 13:46:28        NaN                   Apps
# 1  7/29/2016 13:52:16        NaN                   Apps
# ...

# %%
df['Location'] = 'Sunnyvale'

# %%
df_SV = df

# %%
all_csvs = glob.glob(os.path.join('datasets/NPS/surveys/2016_renamed/weeks1_7/Taipei', '*.csv'))
read_all_csvs = (pd.read_csv(f) for f in all_csvs)
df = pd.concat(read_all_csvs, ignore_index = True, sort = True)
df.head()
# Out:
#    How well is the schedule paced?  \
# 0                                3
# 1                                4
# 2                                3
# 3                                3
# 4                                3
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  4
#
#            Timestamp
# 0  7/29/2016 1:07:23
# 1  7/29/2016 1:08:46
# 2  7/29/2016 1:11:16
# 3  7/29/2016 1:13:23
# 4  7/29/2016 1:13:56

# %%
df['Location'] = 'Taipei'

# %%
df_Taipei = df

# %%
all_csvs = glob.glob(os.path.join('datasets/NPS/surveys/2016_renamed/weeks1_7/Tokyo', '*.csv'))
read_all_csvs = (pd.read_csv(f) for f in all_csvs)
df = pd.concat(read_all_csvs, ignore_index = True, sort = True)
df.head()
# Out:
#    How well is the schedule paced?  \
# 0                                4
# 1                                3
# 2                                1
# 3                                2
# 4                                4
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#            Timestamp
# 0  7/31/2016 1:04:57
# 1  7/31/2016 3:38:14
# 2  7/31/2016 3:59:43
# 3  7/31/2016 4:19:51
# 4  7/31/2016 5:14:20

# %%
df['Location'] = 'Tokyo'

# %%
df_Tokyo = df

# %%
df_Taipei
# Out:
#     How well is the schedule paced?  \
# 0                                 3
# 1                                 4
# 2                                 3
# 3                                 3
# 4                                 3
# 5                                 3
# 6                                 4
# 7                                 3
# 8                                 2
# 9                                 4
# 10                                4
# 11                                3
# 12                                3
# 13                                3
# 14                                3
# 15                                4
# 16                                4
# 17                                3
# 18                                3
# 19                                3
# 20                                3
# 21                                3
# 22                                3
#
# ...

# %%
all_csvs = glob.glob(os.path.join('datasets/NPS/surveys/2016_renamed/weeks1_7/Tokyo', '*.csv'))
read_all_csvs = (pd.read_csv(f) for f in all_csvs)
df = pd.concat(read_all_csvs, ignore_index = True, sort = True)
df.head()
# Out:
#    How well is the schedule paced?  \
# 0                                4
# 1                                3
# 2                                1
# 3                                2
# 4                                4
#
#    How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#            Timestamp
# 0  7/31/2016 1:04:57
# 1  7/31/2016 3:38:14
# 2  7/31/2016 3:59:43
# 3  7/31/2016 4:19:51
# 4  7/31/2016 5:14:20

# %%
df["Location"] = "Tokyo"

# %%
df_Tokyo = df

# %%
df_Tokyo
# Out:
#     How well is the schedule paced?  \
# 0                                 4
# 1                                 3
# 2                                 1
# 3                                 2
# 4                                 4
# 5                                 3
# 6                                 5
# 7                                 2
# 8                                 4
# 9                                 3
# 10                                3
# 11                                4
# 12                                3
#
#     How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                   3
# 1                                                   4
# 2                                                   4
# 3                                                   4
# 4                                                   5
# 5                                                   3
# ...

# %%
dfTest_Tokyo = df_Tokyo

# %%
dfTest_Taipei = df_Taipei

# %%
test = pd.concat([dfTest_Tokyo,dfTest_Taipei])

# %%
test
# Out:
#     How well is the schedule paced?  \
# 0                                 4
# 1                                 3
# 2                                 1
# 3                                 2
# 4                                 4
# 5                                 3
# 6                                 5
# 7                                 2
# 8                                 4
# 9                                 3
# 10                                3
# 11                                4
# 12                                3
# 0                                 3
# 1                                 4
# 2                                 3
# 3                                 3
# 4                                 3
# 5                                 3
# 6                                 4
# 7                                 3
# 8                                 2
# 9                                 4
# 10                                4
# 11                                3
# ...

# %%
test = pd.concat([df_Tokyo, df_Taipei]) #df_HK, df_SV, df_SF, df_NY, df_LA, df_SG

# %%
test
# Out:
#     How well is the schedule paced?  \
# 0                                 4
# 1                                 3
# 2                                 1
# 3                                 2
# 4                                 4
# 5                                 3
# 6                                 5
# 7                                 2
# 8                                 4
# 9                                 3
# 10                                3
# 11                                4
# 12                                3
# 0                                 3
# 1                                 4
# 2                                 3
# 3                                 3
# 4                                 3
# 5                                 3
# 6                                 4
# 7                                 3
# 8                                 2
# 9                                 4
# 10                                4
# 11                                3
# ...

# %%
df_Taipei
# Out:
#     How well is the schedule paced?  \
# 0                                 3
# 1                                 4
# 2                                 3
# 3                                 3
# 4                                 3
# 5                                 3
# 6                                 4
# 7                                 3
# 8                                 2
# 9                                 4
# 10                                4
# 11                                3
# 12                                3
# 13                                3
# 14                                3
# 15                                4
# 16                                4
# 17                                3
# 18                                3
# 19                                3
# 20                                3
# 21                                3
# 22                                3
#
# ...

# %%
test = pd.concat([test, df_HK])
# Out:
# /Users/jamesmccrory/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
frames = [df_HK, df_SV, df_SF, df_NY, df_LA, df_SG, df_Taipei, df_Tokyo]

# %%
df_2016 = pd.concat(frames)
df_2016.head()
# Out:
# /Users/jamesmccrory/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    How well are the tutorials paced? How well is the schedule paced?  \
# 0                                NaN                               3
# 1                                NaN                               3
# 2                                NaN                               3
# 3                                3.0                             NaN
# 4                                3.0                             NaN
#
#   How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  5
# ...

# %%
df_2016.nunique
# Out:
# <bound method DataFrame.nunique of     How well are the tutorials paced? How well is the schedule paced?  \
# 0                                 NaN                               3
# 1                                 NaN                               3
# 2                                 NaN                               3
# 3                                 3.0                             NaN
# 4                                 3.0                             NaN
# 5                                 3.0                             NaN
# 0                                 NaN                               3
# 1                                 NaN                               3
# 2                                 NaN                               4
# 3                                 NaN                               3
# 4                                 NaN                               3
# 5                                 NaN                               3
# ...

# %%
df_2016.describe()
# Out:
#        How well are the tutorials paced?
# count                         216.000000
# mean                            3.384259
# std                             0.658068
# min                             2.000000
# 25%                             3.000000
# 50%                             3.000000
# 75%                             4.000000
# max                             5.000000

# %%
df_2016["Location"].unique()
# Out:
# array(['Hong Kong', 'Sunnyvale', 'San Francisco', 'New York',
#        'Los Angeles', 'Singapore', 'Taipei', 'Tokyo'], dtype=object)

# %%
df_2016
# Out:
#     How well are the tutorials paced? How well is the schedule paced?  \
# 0                                 NaN                               3
# 1                                 NaN                               3
# 2                                 NaN                               3
# 3                                 3.0                             NaN
# 4                                 3.0                             NaN
# 5                                 3.0                             NaN
# 0                                 NaN                               3
# 1                                 NaN                               3
# 2                                 NaN                               4
# 3                                 NaN                               3
# 4                                 NaN                               3
# 5                                 NaN                               3
# ...

# %%
df_2016[(df_2016["Unnamed: 0"].notnull())]
# Out:
#      How well are the tutorials paced? How well is the schedule paced?  \
# 215                                4.0                             NaN
# 216                                4.0                             NaN
# 217                                3.0                             NaN
# 218                                5.0                             NaN
# 219                                3.0                             NaN
# 220                                3.0                             NaN
# 221                                4.0                             NaN
# 222                                3.0                             NaN
# 223                                3.0                             NaN
# 224                                4.0                             NaN
# 225                                3.0                             NaN
# 226                                4.0                             NaN
# ...

# %%
df_2016['Timestamp'] = np.where(df_2016['Timestamp'].isna(), df_2016["Unnamed: 0"], df_2016['Timestamp'])

# %%
df_2016[(df_2016["Unnamed: 0"].notnull())]
# Out:
#      How well are the tutorials paced? How well is the schedule paced?  \
# 215                                4.0                             NaN
# 216                                4.0                             NaN
# 217                                3.0                             NaN
# 218                                5.0                             NaN
# 219                                3.0                             NaN
# 220                                3.0                             NaN
# 221                                4.0                             NaN
# 222                                3.0                             NaN
# 223                                3.0                             NaN
# 224                                4.0                             NaN
# 225                                3.0                             NaN
# 226                                4.0                             NaN
# ...

# %%
df_2016_backup = df_2016.drop(["Unnamed: 0"], axis=1)

# %%
df_2016 = df_2016_backup

# %%
df_2016
# Out:
#     How well are the tutorials paced? How well is the schedule paced?  \
# 0                                 NaN                               3
# 1                                 NaN                               3
# 2                                 NaN                               3
# 3                                 3.0                             NaN
# 4                                 3.0                             NaN
# 5                                 3.0                             NaN
# 0                                 NaN                               3
# 1                                 NaN                               3
# 2                                 NaN                               4
# 3                                 NaN                               3
# 4                                 NaN                               3
# 5                                 NaN                               3
# ...

# %%
df_2016 = df_2016.rename(index=str, columns={"How would you rate your overall satisfaction with the Summer Academy this week?": "Score", "How well are the tutorials paced?": "Schedule Pacing"})

# %%
df_2016
# Out:
#     Schedule Pacing How well is the schedule paced? Score   Location  \
# 0               NaN                               3     5  Hong Kong
# 1               NaN                               3     4  Hong Kong
# 2               NaN                               3     5  Hong Kong
# 3               3.0                             NaN     4  Hong Kong
# 4               3.0                             NaN     5  Hong Kong
# 5               3.0                             NaN     5  Hong Kong
# 0               NaN                               3     4  Sunnyvale
# 1               NaN                               3     5  Sunnyvale
# 2               NaN                               4     5  Sunnyvale
# 3               NaN                               3     4  Sunnyvale
# 4               NaN                               3     3  Sunnyvale
# 5               NaN                               3     3  Sunnyvale
# 6               NaN                               3     4  Sunnyvale
# ...
