# %%
ls
# Out:
# Conditional_Probability.ipynb
# Data Cleaning & Descriptive Statistics.ipynb
# DataVisualization.ipynb
# StatisticalDistributions&Sampling.ipynb
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# Untitled5.ipynb
# class2.ipynb
# jan30thClass.ipynb
# mobileAppTutorial.ipynb
# pokemon_EDA.ipynb

# %%
cd ../
# Out:
# /Users/jamesmccrory/dev/ds1.1

# %%
ls
# Out:
# DataVisualization.ipynb  WITH                     notebooks/
# GAMES                    app_store_tutorial_SEE   pokemon_EDA.ipynb
# US_questions.md          datasets/
# Untitled.ipynb           mobileAppTutorial.ipynb

# %%
DATASET = pd.read("/datasets/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-56f4841cdfe9> in <module>
# ----> 1 DATASET = pd.read("/datasets/titanic.csv")
#
# NameError: name 'pd' is not defined

# %%
import panda as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-f542dbfa5144> in <module>
# ----> 1 import panda as pd
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd

# %%
DATASET = pd.read("/datasets/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-56f4841cdfe9> in <module>
# ----> 1 DATASET = pd.read("/datasets/titanic.csv")
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
DATASET = pd.open("/datasets/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-4ef953420018> in <module>
# ----> 1 DATASET = pd.open("/datasets/titanic.csv")
#
# AttributeError: module 'pandas' has no attribute 'open'

# %%
DATASET = "./datasets/titanic.csv"

# %%
titanic_df = pd.read_csv(DATASET)

# %%
df = titanic_df

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df.histogram()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-9f0abaa2be3f> in <module>
# ----> 1 titanic_df.histogram()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'histogram'

# %%
titanic_df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
titanic_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11facb630>,
# ...
#       dtype=object)

# %%
titanic_df.count((df.age>0) &(df.age<10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d6a50d2c3477> in <module>
# ----> 1 titanic_df.count((df.age>0) &(df.age<10))
#
# NameError: name 'df' is not defined

# %%
titanic_df.count((titanic_df.age>0) &(titanic_df.age<10))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-b9d6bf127759> in <module>
# ----> 1 titanic_df.count((titanic_df.age>0) &(titanic_df.age<10))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'age'

# %%
titanic_df.count((titanic_df.Age>0) &(titanic_df.Age<10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-a7fdac7f4064> in <module>
# ----> 1 titanic_df.count((titanic_df.Age>0) &(titanic_df.Age<10))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in count(self, axis, level, numeric_only)
#    6776         Myla      1
#    6777         """
# -> 6778         axis = self._get_axis_number(axis)
#    6779         if level is not None:
#    6780             return self._count_level(level, axis=axis,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(self, axis)
#     363
#     364     def _get_axis_number(self, axis):
# --> 365         axis = self._AXIS_ALIASES.get(axis, axis)
#     366         if is_integer(axis):
#     367             if axis in self._AXIS_NAMES:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __hash__(self)
# ...

# %%
titanic_df.count((titanic_df[Age]>0) &(titanic_df[Age]<10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-39d7296ad856> in <module>
# ----> 1 titanic_df.count((titanic_df[Age]>0) &(titanic_df[Age]<10))
#
# NameError: name 'Age' is not defined

# %%
titanic_df[(titanic_df[Age]>0) &(titanic_df[Age]<10)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ff78ffa2cf66> in <module>
# ----> 1 titanic_df[(titanic_df[Age]>0) &(titanic_df[Age]<10)]
#
# NameError: name 'Age' is not defined

# %%
titanic_df[(titanic_df.Age>0) &(titanic_df.Age<10)]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 10            11         1       3
# 16            17         0       3
# 24            25         0       3
# 43            44         1       2
# 50            51         0       3
# 58            59         1       2
# 63            64         0       3
# 78            79         1       2
# 119          120         0       3
# 147          148         0       3
# 164          165         0       3
# 165          166         1       3
# 171          172         0       3
# 172          173         1       3
# 182          183         0       3
# 183          184         1       2
# 184          185         1       3
# 193          194         1       2
# 205          206         0       3
# 233          234         1       3
# 237          238         1       2
# 261          262         1       3
# 278          279         0       3
# 297          298         0       1
# ...

# %%
titanic_df[(titanic_df.Age>0) &(titanic_df.Age<10)].count()
# Out:
# PassengerId    62
# Survived       62
# Pclass         62
# Name           62
# Sex            62
# Age            62
# SibSp          62
# Parch          62
# Ticket         62
# Fare           62
# Cabin          10
# Embarked       62
# dtype: int64

# %%
df_titanic.hist(titanic_df[(titanic_df.Age>0) &(titanic_df.Age<10)], titanic_df[(titanic_df.Age>11) &(titanic_df.Age<20)], titanic_df[(titanic_df.Age>21) &(titanic_df.Age<30)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3bf2f4ec8674> in <module>
# ----> 1 df_titanic.hist(titanic_df[(titanic_df.Age>0) &(titanic_df.Age<10)], titanic_df[(titanic_df.Age>11) &(titanic_df.Age<20)], titanic_df[(titanic_df.Age>21) &(titanic_df.Age<30)])
#
# NameError: name 'df_titanic' is not defined

# %%
df_titanic.count(titanic_df[(titanic_df.Age>0) &(titanic_df.Age<10)], titanic_df[(titanic_df.Age>11) &(titanic_df.Age<20)], titanic_df[(titanic_df.Age>21) &(titanic_df.Age<30)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-5045bf70dd96> in <module>
# ----> 1 df_titanic.count(titanic_df[(titanic_df.Age>0) &(titanic_df.Age<10)], titanic_df[(titanic_df.Age>11) &(titanic_df.Age<20)], titanic_df[(titanic_df.Age>21) &(titanic_df.Age<30)])
#
# NameError: name 'df_titanic' is not defined

# %%
titanic_df[(titanic_df.Age>0) &(titanic_df.Age<10)]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 10            11         1       3
# 16            17         0       3
# 24            25         0       3
# 43            44         1       2
# 50            51         0       3
# 58            59         1       2
# 63            64         0       3
# 78            79         1       2
# 119          120         0       3
# 147          148         0       3
# 164          165         0       3
# 165          166         1       3
# 171          172         0       3
# 172          173         1       3
# 182          183         0       3
# 183          184         1       2
# 184          185         1       3
# 193          194         1       2
# 205          206         0       3
# 233          234         1       3
# 237          238         1       2
# 261          262         1       3
# 278          279         0       3
# 297          298         0       1
# ...

# %%
df_titanic[(titanic_df[(titanic_df.Age>0) &(titanic_df.Age<10)], titanic_df[(titanic_df.Age>11) &(titanic_df.Age<20)], titanic_df[(titanic_df.Age>21) &(titanic_df.Age<30)])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-08b558faee91> in <module>
# ----> 1 df_titanic[(titanic_df[(titanic_df.Age>0) &(titanic_df.Age<10)], titanic_df[(titanic_df.Age>11) &(titanic_df.Age<20)], titanic_df[(titanic_df.Age>21) &(titanic_df.Age<30)])]
#
# NameError: name 'df_titanic' is not defined

# %%
df_titanic.hist(titanic_df[(titanic_df.Age>0) &(titanic_df.Age<10)], titanic_df[(titanic_df.Age>11) &(titanic_df.Age<20)], titanic_df[(titanic_df.Age>21) &(titanic_df.Age<30)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-3bf2f4ec8674> in <module>
# ----> 1 df_titanic.hist(titanic_df[(titanic_df.Age>0) &(titanic_df.Age<10)], titanic_df[(titanic_df.Age>11) &(titanic_df.Age<20)], titanic_df[(titanic_df.Age>21) &(titanic_df.Age<30)])
#
# NameError: name 'df_titanic' is not defined

# %%
```import matplotlib.pyplot as plt```
# Out:
#   File "<ipython-input-28-fb8254fde472>", line 1
#     ```import matplotlib.pyplot as plt```
#     ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# %%
df_titanic["Age"].hist(bins=16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-cdb57e3e5a32> in <module>
# ----> 1 df_titanic["Age"].hist(bins=16)
#
# NameError: name 'df_titanic' is not defined

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df_titanic["Age"].hist(bins=16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-cdb57e3e5a32> in <module>
# ----> 1 df_titanic["Age"].hist(bins=16)
#
# NameError: name 'df_titanic' is not defined

# %%
df_titanic[df_titanic["Age"].hist(bins=16)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-2da2805cfee1> in <module>
# ----> 1 df_titanic[df_titanic["Age"].hist(bins=16)]
#
# NameError: name 'df_titanic' is not defined

# %%
df_titanic.Age.hist(bins=16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-67c86508cdab> in <module>
# ----> 1 df_titanic.Age.hist(bins=16)
#
# NameError: name 'df_titanic' is not defined

# %%
df_titanic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-c03c945d30f4> in <module>
# ----> 1 df_titanic
#
# NameError: name 'df_titanic' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df["Age"].hist(bins=16)

# %%
df_titanic["Nan"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-7b1e90da4ac1> in <module>
# ----> 1 df_titanic["Nan"]
#
# NameError: name 'df_titanic' is not defined

# %%
df["Nana"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Nana'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-0ea853ed1d1f> in <module>
# ----> 1 df["Nana"]
#
# ...

# %%
df[Nan]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-596200ed77e2> in <module>
# ----> 1 df[Nan]
#
# NameError: name 'Nan' is not defined

# %%
df["NaN"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NaN'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-76464a95a37f> in <module>
# ----> 1 df["NaN"]
#
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
Gender = "Gender"

# %%
df["Gender"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-be07f10108f8> in <module>
# ----> 1 df["Gender"]
#
# ...

# %%
df["Gender"] = df[(df.sex == "Male") == 1]
# Out:
#   File "<ipython-input-50-155eb619dff8>", line 1
#     df["Gender"] = df[(df.sex == "Male") = 1]
#                                          ^
# SyntaxError: invalid syntax

# %%
df["Gender"] = df["Sex"].map({'female': 0, 'male': 1}).astype('int')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (891, 13)

# %%
df{"age"}
# Out:
#   File "<ipython-input-57-1aa4f19e6dbe>", line 1
#     df{"age"}
#       ^
# SyntaxError: invalid syntax

# %%
df["age"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-b91d07ee8e3b> in <module>
# ----> 1 df["age"]
#
# ...

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"].plot.box()

# %%
df["Age" != "Nan"].plot.box()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-2d6f61c97cc2> in <module>
# ----> 1 df["Age" != "Nan"].plot.box()
#
# ...

# %%
df["Age" != Nan]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-e4991aba183c> in <module>
# ----> 1 df["Age" != Nan]
#
# NameError: name 'Nan' is not defined

# %%
df[df["Age"].notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 30            31         0       1
# ...

# %%
df["Age"].dropna().values
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  , 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  , 31.  , 35.  ,
#        34.  , 15.  , 28.  ,  8.  , 38.  , 19.  , 40.  , 66.  , 28.  ,
#        42.  , 21.  , 18.  , 14.  , 40.  , 27.  ,  3.  , 19.  , 18.  ,
#         7.  , 21.  , 49.  , 29.  , 65.  , 21.  , 28.5 ,  5.  , 11.  ,
#        22.  , 38.  , 45.  ,  4.  , 29.  , 19.  , 17.  , 26.  , 32.  ,
#        16.  , 21.  , 26.  , 32.  , 25.  ,  0.83, 30.  , 22.  , 29.  ,
#        28.  , 17.  , 33.  , 16.  , 23.  , 24.  , 29.  , 20.  , 46.  ,
#        26.  , 59.  , 71.  , 23.  , 34.  , 34.  , 28.  , 21.  , 33.  ,
#        37.  , 28.  , 21.  , 38.  , 47.  , 14.5 , 22.  , 20.  , 17.  ,
#        21.  , 70.5 , 29.  , 24.  ,  2.  , 21.  , 32.5 , 32.5 , 54.  ,
#        12.  , 24.  , 45.  , 33.  , 20.  , 47.  , 29.  , 25.  , 23.  ,
#        19.  , 37.  , 16.  , 24.  , 22.  , 24.  , 19.  , 18.  , 19.  ,
# ...

# %%
df[(df["Sex"] == "Male") & (df["Survived"] == 0)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Gender]
# Index: []

# %%
df[(df["Sex"] == "Male") & (df["Survived"] == "0")]
# Out:
# /Users/jamesmccrory/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py:1167: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-6a689bb4c421> in <module>
# ----> 1 df[(df["Sex"] == "Male") & (df["Survived"] == "0")]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
#    1284             if is_scalar(res):
#    1285                 raise TypeError('Could not compare {typ} type with Series'
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1167                     result = method(y)
# ...

# %%
df[(df["Sex"] == "Male") & (df["Survived"] == '0')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-c68ec34fda76> in <module>
# ----> 1 df[(df["Sex"] == "Male") & (df["Survived"] == '0')]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
#    1284             if is_scalar(res):
#    1285                 raise TypeError('Could not compare {typ} type with Series'
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1167                     result = method(y)
#    1168                 if result is NotImplemented:
# -> 1169                     raise TypeError("invalid type comparison")
#    1170             else:
#    1171                 result = op(x, y)
#
# TypeError: invalid type comparison

# %%
df[(df["Sex"] == "male") & (df["Survived"] == 0)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 26            27         0       3                  Emir, Mr. Farred Chehab
# 27            28         0       1           Fortune, Mr. Charles Alexander
# ...

# %%
df["Age" & ("Embarked" == "C")].hist(bins=16)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-1f437241f9eb> in <module>
# ----> 1 df["Age" & ("Embarked" == "C")].hist(bins=16)
#
# TypeError: unsupported operand type(s) for &: 'str' and 'bool'

# %%
df["Age" for ("Embarked" == "C")].hist(bins=16)
# Out:
#   File "<ipython-input-74-114c047f0f89>", line 1
#     df["Age" for ("Embarked" == "C")].hist(bins=16)
#                ^
# SyntaxError: invalid syntax

# %%
df[df[(["Embarked"] == "C")]["Age"].hist(bins=16)
# Out:
#   File "<ipython-input-77-11a526559e36>", line 1
#     df[df[(["Embarked"] == "C")]["Age"].hist(bins=16)
#                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
df[df[["Embarked"] == "C"]["Age"].hist(bins=16)
# Out:
#   File "<ipython-input-78-c869733ed026>", line 1
#     df[df[["Embarked"] == "C"]["Age"].hist(bins=16)
#                                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
df[df["Embarked"] == "C"]["Age"].hist(bins=16)

# %%
import seaborn as sb

# %%
df["Embarked"].unique
# Out:
# <bound method Series.unique of 0      S
# 1      C
# 2      S
# 3      S
# 4      S
# 5      Q
# 6      S
# 7      S
# 8      S
# 9      C
# 10     S
# 11     S
# 12     S
# 13     S
# 14     S
# 15     S
# 16     Q
# 17     S
# 18     S
# 19     C
# 20     S
# 21     S
# 22     Q
# 23     S
# 24     S
# 25     S
# 26     C
# 27     S
# 28     Q
# 29     S
#       ..
# 861    S
# 862    S
# 863    S
# 864    S
# 865    S
# 866    C
# 867    S
# 868    S
# 869    S
# 870    S
# 871    S
# 872    S
# 873    S
# 874    C
# 875    C
# 876    S
# 877    S
# 878    S
# 879    C
# 880    S
# 881    S
# 882    S
# 883    S
# 884    S
# 885    Q
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object>

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df["Embarked"].unique().count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-318c8256d0de> in <module>
# ----> 1 df["Embarked"].unique().count
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
df["Embarked"].unique.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-c07335ba2b59> in <module>
# ----> 1 df["Embarked"].unique.count()
#
# AttributeError: 'function' object has no attribute 'count'

# %%
df["Embarked"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0      S
# 1      C
# 2      S
# 3      S
# 4      S
# 5      Q
# 6      S
# 7      S
# 8      S
# 9      C
# 10     S
# 11     S
# 12     S
# 13     S
# 14     S
# 15     S
# 16     Q
# 17     S
# 18     S
# 19     C
# 20     S
# 21     S
# 22     Q
# 23     S
# 24     S
# 25     S
# 26     C
# 27     S
# 28     Q
# 29     S
#       ..
# 861    S
# 862    S
# 863    S
# 864    S
# 865    S
# 866    C
# 867    S
# 868    S
# 869    S
# 870    S
# 871    S
# 872    S
# 873    S
# 874    C
# 875    C
# 876    S
# 877    S
# 878    S
# 879    C
# 880    S
# 881    S
# 882    S
# 883    S
# 884    S
# 885    Q
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object>

# %%
df["Embarked"].nunique()
# Out:
# 3

# %%
df['Embarked'].value_counts().plot(kind='bar')

# %%
df['Embarked'].value_counts().plot(kind='bar').invert_yaxis()

# %%
sb.countplot(y="Embarked", palette="winter", data=df)

# %%
sb.countplot(y="Embarked", palette="winter", data=df)

# %%
sb.countplot(y="Embarked", palette="summer", data=df)

# %%
sb.countplot(y="Embarked", palette="fall", data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/seaborn/palettes.py in color_palette(palette, n_colors, desat)
#     231                 # Perhaps a named matplotlib colormap?
# --> 232                 palette = mpl_palette(palette, n_colors)
#     233             except ValueError:
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/palettes.py in mpl_palette(name, n_colors)
#     455     else:
# --> 456         cmap = mpl.cm.get_cmap(name)
#     457         if cmap is None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/cm.py in get_cmap(name, lut)
#     181             "Colormap %s is not recognized. Possible values are: %s"
# --> 182             % (name, ', '.join(sorted(cmap_d))))
#     183
#
# ...

# %%
sb.countplot(y="Embarked", palette="autumn", data=df)

# %%
df[df["Embarked"] == "C"].groupby("Sex")["Age"].plot(bin=16, kind='hist', legend=True, alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].plot(bins=16, kind='hist', legend=True, alpha=0.5)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].describe()
# Out:
#         count       mean       std   min   25%   50%   75%   max
# Sex
# female   61.0  28.344262  15.77083  0.75  17.0  24.0  40.0  60.0
# male     69.0  32.998841  14.90544  0.42  24.0  30.0  40.0  71.0

# %%
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].plot(kind='kde', legend=True, alpha=0.5)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].agg(np.mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-c35d358650c5> in <module>
# ----> 1 df[df['Embarked'] == 'C'].groupby('Sex')['Age'].agg(np.mean)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].agg(np.mean)
# Out:
# Sex
# female    28.344262
# male      32.998841
# Name: Age, dtype: float64
