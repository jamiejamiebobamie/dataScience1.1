# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np
from scipy import stats

# %%
DATASET1 = "datasets/kickstarter/ks_201612.csv"

# %%
DATASET2 = "datasets/kickstarter/ks_201801.csv"

# Note: datasets/kickstarter/ks_201612.csv gives a codec error when read.

# df1 = pd.read_csv(DATASET1) 

# df1
# df1.describe()

# %%
df = pd.read_csv(DATASET2)

# %%
df
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# 5       1000014025                               Monarch Espresso Bar
# 6       1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 7       1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 8       1000034518  SPIN - Premium Retractable In-Ear Headphones w...
# 9        100004195  STUDIO IN THE SKY - A Documentary Feature Film...
# 10       100004721                                Of Jesus and Madmen
# 11       100005484                                   Lisa Lim New CD!
# ...

# %%
# DATASET SOURCE : https://www.kaggle.com/kemical/kickstarter-projects/version/7#_=_

# %%
df['pledged'].max()
# Out:
# 20338986.27

# %%
df[df['pledged'] == 20338986.27]
# Out:
#                 ID                                              name  \
# 157270  1799979574  Pebble Time - Awesome Smartwatch, No Compromises
#
#               category main_category currency    deadline      goal  \
# 157270  Product Design        Design      USD  2015-03-28  500000.0
#
#                    launched      pledged       state  backers country  \
# 157270  2015-02-24 15:44:42  20338986.27  successful    78471      US
#
#         usd pledged  usd_pledged_real  usd_goal_real
# 157270  20338986.27       20338986.27       500000.0

# %%
#https://en.wikipedia.org/wiki/Pebble_Time

# %%
# what is the range of pledged dollars for successful projects in this category?
# (ie how extraordinry is this pledge amount in the scope of this domain?)
success = df[df['state'] == "successful"]

# %%
sns.barplot(x="category", y='pledged', palette="winter", data=success)
# Out:
# /Users/jamesmccrory/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
success['category'].count()
# Out:
# 133956

# %%
df['year'] = df.deadline.str[:4]

# %%
df
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# 5       1000014025                               Monarch Espresso Bar
# 6       1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 7       1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 8       1000034518  SPIN - Premium Retractable In-Ear Headphones w...
# 9        100004195  STUDIO IN THE SKY - A Documentary Feature Film...
# 10       100004721                                Of Jesus and Madmen
# 11       100005484                                   Lisa Lim New CD!
# ...

# %%
df['year'].unique()
# Out:
# array(['2015', '2017', '2013', '2012', '2016', '2014', '2011', '2018',
#        '2010', '2009'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 16 columns):
# ID                  378661 non-null int64
# name                378657 non-null object
# category            378661 non-null object
# main_category       378661 non-null object
# currency            378661 non-null object
# deadline            378661 non-null object
# goal                378661 non-null float64
# launched            378661 non-null object
# pledged             378661 non-null float64
# state               378661 non-null object
# backers             378661 non-null int64
# country             378661 non-null object
# usd pledged         374864 non-null float64
# usd_pledged_real    378661 non-null float64
# usd_goal_real       378661 non-null float64
# year                378661 non-null object
# dtypes: float64(5), int64(2), object(9)
# memory usage: 46.2+ MB

# %%
# from https://www.kaggle.com/ahmetuzgor/kickstarter-projects-analyzing:
f,ax=plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,linewidths=.5,fmt=".2f",ax=ax)
plt.show()

# %%
dataFrame = ks2018data.drop(['ID'],1)
dataFrame['duration'] = (dataFrame['deadline'] - dataFrame['launched']).dt.days
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f7067efd9da2> in <module>
# ----> 1 dataFrame = ks2018data.drop(['ID'],1)
#       2 dataFrame['duration'] = (dataFrame['deadline'] - dataFrame['launched']).dt.days
#
# NameError: name 'ks2018data' is not defined

# %%
type(df['launched'])
# Out:
# pandas.core.series.Series

# %%
type(df['launched'][0])
# Out:
# str

# %%
# dfBackup = pd.to_datetime(df['launched'])
df_backup = df

# %%
df['launched'] = pd.to_datetime(df['launched'])

# %%
type(df['launched'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['deadline'] = pd.to_datetime(df['deadline'])

# %%
type(df['deadline'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['duration'] = (df['deadline'] - df['launched']).dt.days

# %%
df
# Out:
#                                                      name          category  \
# 0                         The Songs of Adelaide & Abullah            Poetry
# 1           Greeting From Earth: ZGAC Arts Capsule For ET    Narrative Film
# 2                                          Where is Hank?    Narrative Film
# 3       ToshiCapital Rekordz Needs Help to Complete Album             Music
# 4       Community Film Project: The Art of Neighborhoo...      Film & Video
# 5                                    Monarch Espresso Bar       Restaurants
# 6       Support Solar Roasted Coffee & Green Energy!  ...              Food
# 7       Chaser Strips. Our Strips make Shots their B*tch!            Drinks
# 8       SPIN - Premium Retractable In-Ear Headphones w...    Product Design
# 9       STUDIO IN THE SKY - A Documentary Feature Film...       Documentary
# 10                                    Of Jesus and Madmen        Nonfiction
# ...

# %%
# from https://www.kaggle.com/ahmetuzgor/kickstarter-projects-analyzing:
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
state_count = df.state.value_counts()
print(state_count)
x=state_count.index
y2=state_count.values


y_pos = np.arange(len(x))

 
plt.bar(y_pos, y2, align='center', alpha=0.7)
plt.xticks(y_pos, x)
plt.ylabel('Project Company Numbers')
plt.title('State of Projects')
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-fcda423cf931> in <module>
#       1 # from https://www.kaggle.com/ahmetuzgor/kickstarter-projects-analyzing:
# ----> 2 figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#       3 state_count = df.state.value_counts()
#       4 print(state_count)
#       5 x=state_count.index
#
# NameError: name 'figure' is not defined

# %%
# from https://www.kaggle.com/ahmetuzgor/kickstarter-projects-analyzing:
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from matplotlib.pyplot import figure
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os

# Any results you write to the current directory are saved as output.

# %%
# from https://www.kaggle.com/ahmetuzgor/kickstarter-projects-analyzing:
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
state_count = df.state.value_counts()
print(state_count)
x=state_count.index
y2=state_count.values


y_pos = np.arange(len(x))

 
plt.bar(y_pos, y2, align='center', alpha=0.7)
plt.xticks(y_pos, x)
plt.ylabel('Project Company Numbers')
plt.title('State of Projects')
 
plt.show()
# Out:
# failed        197719
# successful    133956
# canceled       38779
# undefined       3562
# live            2799
# suspended       1846
# Name: state, dtype: int64

# %%
# from https://www.kaggle.com/ahmetuzgor/kickstarter-projects-analyzing:
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','orange','gray']
explode = (0.1, 0.1, 0, 0,0.0,0.1)  # explode 1st slice
# Plot
plt.pie(y2, explode=explode, labels=x, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=90)
 
plt.axis('equal')
# from https://www.kaggle.com/ahmetuzgor/kickstarter-projects-analyzing:plt.show()

# %%
# from https://www.kaggle.com/ahmetuzgor/kickstarter-projects-analyzing:
# Successfull comparison considering country plotted belove
successful_projects = df['state']== "successful"
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
a = df[successful_projects]
country_count = a.country.value_counts()
countries=country_count.index
y=country_count.values
y_pos = np.arange(len(countries))
print(countries,y)
# Successful Projects number comoarison
plt.bar(y_pos, y, align='center', alpha=0.7)
plt.xticks(y_pos, countries)
plt.ylabel('Project Numbers in Countries')
plt.title('Countries Successful Project Numbers')
 
plt.show()

# All projects number comparison
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
c_count = df.country.value_counts()
b= c_count.index
c = c_count.values
y_pos = np.arange(len(b))
print(b,c)
plt.bar(y_pos, c , align='center', alpha = 0.6)
plt.xticks(y_pos, b)
plt.ylabel('Project Numbers in Countries')
plt.title('Countries All Project Numbers')
plt.show()
# Out:
# Index(['US', 'GB', 'CA', 'AU', 'DE', 'FR', 'NL', 'SE', 'ES', 'NZ', 'IT', 'MX',
#        'DK', 'HK', 'IE', 'CH', 'SG', 'NO', 'BE', 'AT', 'N,0"', 'LU', 'JP'],
#       dtype='object') [109299  12067   4134   2010    937    908    617    509    492    448
#     439    396    360    216    207    187    178    162    152    107
#     105     19      7]
# Index(['US', 'GB', 'CA', 'AU', 'DE', 'N,0"', 'FR', 'IT', 'NL', 'ES', 'SE',
#        'MX', 'NZ', 'DK', 'IE', 'CH', 'NO', 'HK', 'BE', 'AT', 'SG', 'LU', 'JP'],
#       dtype='object') [292627  33672  14756   7839   4171   3797   2939   2878   2868   2276
#    1757   1752   1447   1113    811    761    708    618    617    597
#     555     62     40]

# %%
# from https://www.kaggle.com/ahmetuzgor/kickstarter-projects-analyzing:
#Percentages of successful projects out of all projects cosidering countries
from random import *
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
i = 0.1
array_data = []
for x in range(100,200):
    i = uniform(0.6295,0.6435)
    array_data.append(i)
bData = array_data
success_ratio_of_countries = np.array(y*100)/np.array(c)

y_pos = np.arange(len(countries))

plt.bar(y_pos, success_ratio_of_countries , align='center', alpha = 0.6)
plt.xticks(y_pos, countries)
plt.ylabel('Success Percentage (%)')
plt.title('Country Success Percentage out of all Projects ')
plt.show()

plt.show()

# %%
df
# Out:
#                                                      name          category  \
# 0                         The Songs of Adelaide & Abullah            Poetry
# 1           Greeting From Earth: ZGAC Arts Capsule For ET    Narrative Film
# 2                                          Where is Hank?    Narrative Film
# 3       ToshiCapital Rekordz Needs Help to Complete Album             Music
# 4       Community Film Project: The Art of Neighborhoo...      Film & Video
# 5                                    Monarch Espresso Bar       Restaurants
# 6       Support Solar Roasted Coffee & Green Energy!  ...              Food
# 7       Chaser Strips. Our Strips make Shots their B*tch!            Drinks
# 8       SPIN - Premium Retractable In-Ear Headphones w...    Product Design
# 9       STUDIO IN THE SKY - A Documentary Feature Film...       Documentary
# 10                                    Of Jesus and Madmen        Nonfiction
# ...

# %%
top_318 = df[(df['state'] == 'successful') & (df['pledged'] > 1000000)]

# %%
top_318['category'].unique()
# Out:
# array(['Hardware', 'Technology', 'Product Design', 'Design',
#        'Gaming Hardware', 'Tabletop Games', 'Video Games', 'Gadgets',
#        'Food', 'Mixed Media', 'Fabrication Tools', 'Movie Theaters',
#        'Sound', 'Apparel', 'Wearables', '3D Printing', 'Robots',
#        'Camera Equipment', 'Sculpture', 'Typography', 'Television',
#        'Space Exploration', 'Narrative Film', 'Art', 'Accessories',
#        'Flight', 'Software', 'Comics', 'Illustration', 'Childrenswear',
#        'Drinks', 'Crafts', 'Public Art', 'Web', 'World Music', 'Farms',
#        'Fashion', 'Games', 'Footwear', 'Documentary', 'Music',
#        'DIY Electronics'], dtype=object)

# %%
ax = sns.lineplot(x="duration", y="goal", hue="state", style="state", markers=True, dashes=False, data=df)

# %%
remove_outliers = df[df['duration'] < 1000]

# %%
ax = sns.lineplot(x="duration", y="goal", hue="state", style="state", markers=True, dashes=False, data=remove_outliers)

# %%
sns.countplot(x="state", hue="year", data=df)

# %%
df[(df['year'] == '2009') & (df['state'] == 'successful')].count()/df[df['year'] == '2009'].count()
# Out:
# name                0.425721
# category            0.425721
# main_category       0.425721
# currency            0.425721
# deadline            0.425721
# goal                0.425721
# launched            0.425721
# pledged             0.425721
# state               0.425721
# backers             0.425721
# country             0.425721
# usd pledged         0.425721
# usd_pledged_real    0.425721
# usd_goal_real       0.425721
# year                0.425721
# duration            0.425721
# dtype: float64

# %%
type(df['year'].unique())
# Out:
# numpy.ndarray

# %%
successes = {}
for year in df['year'].unique():
    successes[str(year)] = df[(df['year'] == str(year)) & (df['state'] == 'successful')].count()/df[df['year'] == str(year)].count()
#     df['Success%'] = np.where((df['year'] == str(year)) & (df['state'] == 'successful'), df[(df['year'] == str(year)) & (df['state'] == 'successful')].count()/df[df['year'] == str(year)].count(), df[(df['year'] == str(year)) & (df['state'] == 'successful')].count()/df[df['year'] == str(year)].count())
    #df['percent success'] = df[(df['year'] == str(year)) & (df['state'] == 'successful')].count()/df[df['year'] == str(year)].count()

# %%
df
# Out:
#                                                      name          category  \
# 0                         The Songs of Adelaide & Abullah            Poetry
# 1           Greeting From Earth: ZGAC Arts Capsule For ET    Narrative Film
# 2                                          Where is Hank?    Narrative Film
# 3       ToshiCapital Rekordz Needs Help to Complete Album             Music
# 4       Community Film Project: The Art of Neighborhoo...      Film & Video
# 5                                    Monarch Espresso Bar       Restaurants
# 6       Support Solar Roasted Coffee & Green Energy!  ...              Food
# 7       Chaser Strips. Our Strips make Shots their B*tch!            Drinks
# 8       SPIN - Premium Retractable In-Ear Headphones w...    Product Design
# 9       STUDIO IN THE SKY - A Documentary Feature Film...       Documentary
# 10                                    Of Jesus and Madmen        Nonfiction
# ...

# %%
successes
# Out:
# {'2015': name                0.271943
#  category            0.271943
#  main_category       0.271943
#  currency            0.271943
#  deadline            0.271943
#  goal                0.271943
#  launched            0.271943
#  pledged             0.271943
#  state               0.271943
#  backers             0.271943
#  country             0.271943
#  usd pledged         0.280346
#  usd_pledged_real    0.271943
#  usd_goal_real       0.271943
#  year                0.271943
#  duration            0.271943
#  dtype: float64, '2017': name                0.366849
#  category            0.366849
#  main_category       0.366849
#  currency            0.366849
#  deadline            0.366849
#  goal                0.366849
#  launched            0.366849
#  pledged             0.366849
#  state               0.366849
#  backers             0.366849
#  country             0.366849
#  usd pledged         0.366849
#  usd_pledged_real    0.366849
#  usd_goal_real       0.366849
# ...

# %%
df['Success%'] = np.where(df['year'] == '2015', 27, df['Success%'])

df['Success%'] = np.where(df['year'] == '2017', 37, df['Success%'])

df['Success%'] = np.where(df['year'] == '2013', 43, df['Success%'])

df['Success%'] = np.where(df['year'] == '2012', 43, df['Success%'])

df['Success%'] = np.where(df['year'] == '2016', 32, df['Success%'])

df['Success%'] = np.where(df['year'] == '2014', 32, df['Success%'])

df['Success%'] = np.where(df['year'] == '2011', 46, df['Success%'])

df['Success%'] = np.where(df['year'] == '2018', 26, df['Success%'])

df['Success%'] = np.where(df['year'] == '2010', 44, df['Success%'])

df['Success%'] = np.where(df['year'] == '2009', 42, df['Success%'])

# %%
df
# Out:
#                                                      name          category  \
# 0                         The Songs of Adelaide & Abullah            Poetry
# 1           Greeting From Earth: ZGAC Arts Capsule For ET    Narrative Film
# 2                                          Where is Hank?    Narrative Film
# 3       ToshiCapital Rekordz Needs Help to Complete Album             Music
# 4       Community Film Project: The Art of Neighborhoo...      Film & Video
# 5                                    Monarch Espresso Bar       Restaurants
# 6       Support Solar Roasted Coffee & Green Energy!  ...              Food
# 7       Chaser Strips. Our Strips make Shots their B*tch!            Drinks
# 8       SPIN - Premium Retractable In-Ear Headphones w...    Product Design
# 9       STUDIO IN THE SKY - A Documentary Feature Film...       Documentary
# 10                                    Of Jesus and Madmen        Nonfiction
# ...

# %%
sns.countplot(x="Success%", hue="year", data=df[df['state'] == 'successful'])

# %% [markdown]
# ## The above graph is interesting because it shows the count of the total successful projects per year as well as their correlating percentages. So while 2015 only had 27% successful projects they also had about the same number of successes as every other (recent) year.

# %%
df['category'].unique()
# Out:
# array(['Poetry', 'Narrative Film', 'Music', 'Film & Video', 'Restaurants',
#        'Food', 'Drinks', 'Product Design', 'Documentary', 'Nonfiction',
#        'Indie Rock', 'Crafts', 'Games', 'Tabletop Games', 'Design',
#        'Comic Books', 'Art Books', 'Fashion', 'Childrenswear', 'Theater',
#        'Comics', 'DIY', 'Webseries', 'Animation', 'Food Trucks',
#        'Public Art', 'Illustration', 'Photography', 'Pop', 'People',
#        'Art', 'Family', 'Fiction', 'Accessories', 'Rock', 'Hardware',
#        'Software', 'Weaving', 'Gadgets', 'Web', 'Jazz', 'Ready-to-wear',
#        'Festivals', 'Video Games', 'Anthologies', 'Publishing', 'Shorts',
#        'Electronic Music', 'Radio & Podcasts', 'Apps', 'Cookbooks',
#        'Apparel', 'Metal', 'Comedy', 'Hip-Hop', 'Periodicals', 'Dance',
#        'Technology', 'Painting', 'World Music', 'Photobooks', 'Drama',
#        'Architecture', 'Young Adult', 'Latin', 'Mobile Games', 'Flight',
# ...

# %%
len(df['category'].unique())
# Out:
# 159

# %% [markdown]
# How do I reduce these categories to something manageable?

# %%
import random as rand

# %%
df['category'].unique()[rand.randint(0,len(df['category'].unique())-1)]
# Out:
# 'Video Art'

# %% [markdown]
# ##"Your client is a video artist who's made a name for himself in the brick-and-mortar world of the art gallery. Now he's looking to switch and begin selling his art through Kickstarter. He wants to know anything you can tell him that might help him sell more of his 'Video Art'."
