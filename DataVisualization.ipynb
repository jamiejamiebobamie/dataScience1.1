# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
DATASET = "titanic.csv"

# %%
titanic_df = pd.read_csv(DATASET)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.countplot(x="Embarked", palette="spring", data=titanic_df)

# %%
sns.barplot(x="Sex", y="Survived", hue="Pclass", data=titanic_df)
# Out:
# /Users/jamesmccrory/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.regplot(x="Age", y="Fare", fit_reg=False, data=titanic_df)

# %%
sns.regplot(x="Age", y="Fare", fit_reg=False, data=titanic_df, scatter_kws={"s": titanic_df["SibSp"]*40})

# %%
sns.lmplot(x="Age", y="Fare", fit_reg=False, data=titanic_df, hue="Pclass")

# %%
sns.lmplot(x="Age", y="Fare", fit_reg=False, data=titanic_df, hue="Pclass", 
           scatter_kws={"s": titanic_df["Pclass"]*10}, markers=["o", "*", "x"])

# %%
sns.lmplot(x="Age", y="Fare", fit_reg=False, data=titanic_df, hue="Pclass", 
           scatter_kws={"s": titanic_df["Pclass"]*10}, markers=["o", "*", "x"])

# %%
sns.regplot(x="Pclass", y="Fare", fit_reg=False, x_jitter=.1, y_jitter=.5, data=titanic_df)

# %%
sns.stripplot(x="Pclass", y="Fare", data=titanic_df, jitter=True)

# %%
sns.stripplot(x="Pclass", y="Fare", data=titanic_df, jitter=True, hue="Sex")

# %%
sns.swarmplot(x="Pclass", y="Fare", data=titanic_df)

# %%
sns.swarmplot(x="Pclass", y="Fare", data=titanic_df, hue="Sex")

# %%
sns.swarmplot(x="Pclass", y="Fare", data=titanic_df, hue="Sex", dodge=True)

# %% [markdown]
# ###How many underage passengers (<18) and how many survived?

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_df[("Survived" == 1) & ("Age" < 18)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-05ea05bb4a26> in <module>
# ----> 1 titanic_df[("Survived" == 1) & ("Age" < 18)]
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
titanic_df[(titanic_df.Survived == 1) & (titanic_df.Age < 18)]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 10            11         1       3
# 22            23         1       3
# 39            40         1       3
# 43            44         1       2
# 58            59         1       2
# 68            69         1       3
# 78            79         1       2
# 84            85         1       2
# 125          126         1       3
# 156          157         1       3
# 165          166         1       3
# 172          173         1       3
# 183          184         1       2
# 184          185         1       3
# 193          194         1       2
# 208          209         1       3
# 220          221         1       3
# 233          234         1       3
# 237          238         1       2
# 261          262         1       3
# 305          306         1       1
# 307          308         1       1
# 329          330         1       1
# 340          341         1       2
# ...

# %%
df = titanic_df.copy()

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_df[(titanic_df.Age < 18)]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# 16            17         0       3
# 22            23         1       3
# 24            25         0       3
# 39            40         1       3
# 43            44         1       2
# 50            51         0       3
# 58            59         1       2
# 59            60         0       3
# 63            64         0       3
# 68            69         1       3
# 71            72         0       3
# 78            79         1       2
# 84            85         1       2
# 86            87         0       3
# 111          112         0       3
# 114          115         0       3
# 119          120         0       3
# 125          126         1       3
# 138          139         0       3
# 147          148         0       3
# 156          157         1       3
# ...

# %%
titanic_df[(titanic_df.Age < 18)]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# 16            17         0       3
# 22            23         1       3
# 24            25         0       3
# 39            40         1       3
# 43            44         1       2
# 50            51         0       3
# 58            59         1       2
# 59            60         0       3
# 63            64         0       3
# 68            69         1       3
# 71            72         0       3
# 78            79         1       2
# 84            85         1       2
# 86            87         0       3
# 111          112         0       3
# 114          115         0       3
# 119          120         0       3
# 125          126         1       3
# 138          139         0       3
# 147          148         0       3
# 156          157         1       3
# ...

# %%
df = titanic_df[(titanic_df.Age < 18)]

# %%
sns.swarmplot(x="Survived", y="Age", data=df, hue="Sex", dodge=True)

# %% [markdown]
# What were the survival rate of children in regard to their class (P1-3)?

# %%
sns.swarmplot(x="Survived", y="Age", data=df, hue="Pclass", dodge=True)

# %% [markdown]
# What is the profile of the one Pclass1 child who did not survive?

# %%
df[(df.Pclass == 1) & (df.Survived == 0)]
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  Age  \
# 297          298         0       1  Allison, Miss. Helen Loraine  female  2.0
#
#      SibSp  Parch  Ticket    Fare    Cabin Embarked
# 297      1      2  113781  151.55  C22 C26        S

# %% [markdown]
# NOTE:
#
# "GOOD: How many passengers aboard the Titanic were female and between the ages of 20-30?
# BAD: What's the likelihood that a male passenger who survived is over the age of 60?"
#
# Why are these questions good / bad?
